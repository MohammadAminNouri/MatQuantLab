# %% [markdown]
# # 05 — Backtest With Costs

# %% [markdown]
# Run the code cells in order. This notebook is part of the MatQuantLab research pipeline.

# %%
import pandas as pd
pd.read_csv("outputs/tables/backtest_summary.csv")
