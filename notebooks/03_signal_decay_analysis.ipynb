# %% [markdown]
# # 03 — Signal Decay Analysis

# %% [markdown]
# Run the code cells in order. This notebook is part of the MatQuantLab research pipeline.

# %%
# !python scripts/generate_research_report.py --horizon 20
import pandas as pd
pd.read_csv("outputs/tables/signal_decay.csv").head()
