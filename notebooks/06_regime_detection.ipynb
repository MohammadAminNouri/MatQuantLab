# %% [markdown]
# # 06 — Regime Detection

# %% [markdown]
# Run the code cells in order. This notebook is part of the MatQuantLab research pipeline.

# %%
import pandas as pd
pd.read_csv("outputs/tables/regimes.csv").head()
