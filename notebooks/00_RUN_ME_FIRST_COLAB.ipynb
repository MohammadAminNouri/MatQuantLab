# %% [markdown]
# # 00 — Run Me First in Colab

# %% [markdown]
# This notebook runs the complete MatQuantLab pipeline from GitHub/Colab.

# %%
# In Colab, run this cell after uploading/cloning the repo.
# !pip install -q -r requirements.txt
# !pip install -q -e .
# !python scripts/run_all.py

# %%
from pathlib import Path
print(Path('outputs/research_summary.md').read_text())
